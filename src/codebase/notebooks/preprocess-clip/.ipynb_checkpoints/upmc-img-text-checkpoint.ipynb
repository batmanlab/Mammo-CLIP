# %%
import pandas as pd
from pathlib import Path
import re
import nltk
import numpy as np
from collections import defaultdict
import ast

# %% [markdown]
# ## Annonymize UPMC

# %%
data_dir = Path("/restricted/projectnb/batmanlab/shawn24/PhD/Mammo-CLIP/src/codebase/data_csv")
csv = "upmc_dicom_consolidated_final_folds_BIRADS_num_1_report.csv"
df = pd.read_csv(data_dir/csv)
print(df.shape)
df.head(4)
# Out:
# (76251, 21)
#    patient_id  GENDER  AGE  NOTE_CSN_STUDY_ID BIRADS_CATEGORY  \
# 0    40421851  FEMALE   47          884708601        BIRADS 0
# 1    40421851  FEMALE   47          884708601        BIRADS 0
# 2   936277906  FEMALE   78          831725898        BIRADS 2
# 3   936277906  FEMALE   78          831725898        BIRADS 2
#
#                                              HISTORY  \
# 0                                                NaN
# 1                                                NaN
# 2     The patient is 78 years old and presents fo...
# 3     The patient is 78 years old and presents fo...
#
#                                             FINDINGS  \
# 0     There is a small oval asymmetry anterior de...
# 1     There is a small oval asymmetry anterior de...
# 2     Bilateral digital mammography with CAD\nrev...
# 3     Bilateral digital mammography with CAD\nrev...
#
#                                           IMPRESSION  \
# 0  BI-RADS CATEGORY 0. The patient is 47 years ol...
# 1  BI-RADS CATEGORY 0. The patient is 47 years ol...
# 2  BI-RADS CATEGORY 2. The patient is 78 years ol...
# 3  BI-RADS CATEGORY 2. The patient is 78 years ol...
#
#                                            ASSESMENT  \
# 0                                                NaN
# 1                                                NaN
# 2    BI-RADS: 2 - BENIGN FINDING(S)\n\nRIS CODE: ...
# 3    BI-RADS: 2 - BENIGN FINDING(S)\n\nRIS CODE: ...
#
#                                        RECOMENDATION  ...  CLIP  \
# 0                                                NaN  ...     0
# 1                                                NaN  ...     0
# 2   \nRoutine screening mammography or combinatio...  ...     0
# 3   \nRoutine screening mammography or combinatio...  ...     0
#
#                                             image_id fold  view laterality  \
# 0  1.2.840.113654.2.70.1.250833044448633383274960...    2    CC          R
# 1  1.2.840.113654.2.70.1.218018924783571581641971...    2    CC          R
# 2  1.2.840.113654.2.70.1.159160858633911675764962...    2    CC          R
# 3  1.2.840.113654.2.70.1.104389345981935981355845...    2   MLO          R
#
#   img_size_row  img_size_column  BIRADS_numeric  \
# 0         2456             1995               0
# 1         2456             1995               0
# 2         4096             3328               2
# 3         4096             3328               2
#
#                                               REPORT  \
# 0     There is a small oval asymmetry anterior de...
# 1     There is a small oval asymmetry anterior de...
# 2     Bilateral digital mammography with CAD\nrev...
# 3     Bilateral digital mammography with CAD\nrev...
#
#                                                 text
# 0  there is a small oval asymmetry anterior depth...
# 1  there is a small oval asymmetry anterior depth...
# 2  bilateral digital mammography with cad reveals...
# 3  bilateral digital mammography with cad reveals...
#
# [4 rows x 21 columns]

# %%
import pandas as pd
import random

df = df.head(100)
# Function to generate synthetic report text
def generate_synthetic_text(template):
    conditions = [
        "no significant abnormality detected",
        "benign calcifications present",
        "suspicious mass identified requiring further evaluation",
        "asymmetrical breast density observed",
        "fibroglandular densities noted",
        "microcalcifications detected in the upper quadrant",
        "architectural distortion with no associated mass",
        "lymph node with cortical thickening",
        "solitary dilated duct visible",
        "biopsy recommended for suspicious lesion",
        "implants intact with no evidence of rupture",
        "post-surgical changes evident",
        "benign lymph node enlargement",
        "diffuse skin thickening",
        "possible intramammary lymph node",
        "fibrocystic changes with multiple cysts",
        "normal axillary appearance",
        "previous excisional biopsy site noted",
        "scattered fibroglandular tissue"
    ]
    findings = random.choice(conditions)
    return template.replace("{findings}", findings)

# Function to anonymize findings and impressions
def anonymize_reports(df, id_cols, text_cols):
    anonymized_dict = {}  # Dictionary to store original and anonymized mappings
    for index, row in df.iterrows():
        key = tuple(row[col] for col in id_cols)  # Create a unique key for each patient_id and laterality
        for col in text_cols:
            if key + (row[col],) not in anonymized_dict:
                # Generate synthetic text based on a template
                template = "The examination shows {findings}. Further examination may be needed."
                synthetic_text = generate_synthetic_text(template)
                anonymized_dict[key + (row[col],)] = synthetic_text
            # Replace the original text with the synthetic text
            df.at[index, col] = anonymized_dict[key + (row[col],)]

    return df

# Anonymize the data
id_columns = ['patient_id', 'laterality']
text_columns = ["FINDINGS"]
df = anonymize_reports(df, id_columns, text_columns)

# df.drop('REPORT', axis=1, inplace=True)
# df.drop('text', axis=1, inplace=True)

# %%
import pandas as pd
import random

# Possible conditions for the random text in impressions
impression_texts = [
    "further imaging evaluation is suggested",
    "routine mammographic screening recommended",
    "patient should consider clinical follow-up",
    "follow-up and possible biopsy necessary",
    "no additional imaging required at this time",
    "recommend MRI for better evaluation"
]

# Function to generate synthetic impressions
def generate_synthetic_impressions():
    birads = random.randint(0, 6)  # Random BIRADS number between 0 and 6
    age = random.randint(25, 90)  # Random age between 25 and 90
    text = random.choice(impression_texts)  # Random text from predefined phrases
    return f"Birads: {birads}, Patient is: {age} years old, and {text}"

# Function to anonymize reports specifically for the impressions column
def anonymize_impressions(df, id_cols, text_col):
    anonymized_dict = {}  # Dictionary to store mappings
    for index, row in df.iterrows():
        key = tuple(row[col] for col in id_cols)  # Create a unique key based on patient_id and laterality
        if key not in anonymized_dict:
            # Generate synthetic impressions text
            synthetic_text = generate_synthetic_impressions()
            anonymized_dict[key] = synthetic_text
        # Replace the original text with the synthetic text
        df.at[index, text_col] = anonymized_dict[key]

    return df

# Example DataFrame loading and processing
id_columns = ['patient_id', 'laterality']
df = anonymize_impressions(df, id_columns, 'IMPRESSION')

# %%
df
# Out:
#     patient_id  GENDER  AGE  NOTE_CSN_STUDY_ID BIRADS_CATEGORY  \
# 0     40421851  FEMALE   47          884708601        BIRADS 0
# 1     40421851  FEMALE   47          884708601        BIRADS 0
# 2    936277906  FEMALE   78          831725898        BIRADS 2
# 3    936277906  FEMALE   78          831725898        BIRADS 2
# 4    936277906  FEMALE   78          831725898        BIRADS 2
# ..         ...     ...  ...                ...             ...
# 95    40487189  FEMALE   89          825133346        BIRADS 1
# 96    40487189  FEMALE   89          825133346        BIRADS 1
# 97    40487189  FEMALE   89          825133346        BIRADS 1
# 98    40487189  FEMALE   89          825133346        BIRADS 1
# 99   936195341  FEMALE   49          846903849        BIRADS 1
#
#                                               HISTORY  \
# 0                                                 NaN
# 1                                                 NaN
# 2      The patient is 78 years old and presents fo...
# 3      The patient is 78 years old and presents fo...
# 4      The patient is 78 years old and presents fo...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99     The patient is 49 years old and presents fo...
#
#                                              FINDINGS  \
# 0   The examination shows biopsy recommended for s...
# 1   The examination shows biopsy recommended for s...
# 2   The examination shows no significant abnormali...
# 3   The examination shows no significant abnormali...
# 4   The examination shows benign calcifications pr...
# ..                                                ...
# 95  The examination shows diffuse skin thickening....
# 96  The examination shows architectural distortion...
# 97  The examination shows architectural distortion...
# 98  The examination shows diffuse skin thickening....
# 99  The examination shows solitary dilated duct vi...
#
#                                            IMPRESSION  \
# 0   Birads: 4, Patient is: 47 years old, and furth...
# 1   Birads: 4, Patient is: 47 years old, and furth...
# 2   Birads: 1, Patient is: 48 years old, and routi...
# 3   Birads: 1, Patient is: 48 years old, and routi...
# 4   Birads: 1, Patient is: 52 years old, and follo...
# ..                                                ...
# 95  Birads: 5, Patient is: 86 years old, and patie...
# 96  Birads: 5, Patient is: 28 years old, and patie...
# 97  Birads: 5, Patient is: 28 years old, and patie...
# 98  Birads: 5, Patient is: 86 years old, and patie...
# 99  Birads: 4, Patient is: 70 years old, and no ad...
#
#                                             ASSESMENT  \
# 0                                                 NaN
# 1                                                 NaN
# 2     BI-RADS: 2 - BENIGN FINDING(S)\n\nRIS CODE: ...
# 3     BI-RADS: 2 - BENIGN FINDING(S)\n\nRIS CODE: ...
# 4     BI-RADS: 2 - BENIGN FINDING(S)\n\nRIS CODE: ...
# ..                                                ...
# 95     BI-RADS: 1 - NEGATIVE\n\nRIS CODE: 2NEGATIVE\n
# 96     BI-RADS: 1 - NEGATIVE\n\nRIS CODE: 2NEGATIVE\n
# 97     BI-RADS: 1 - NEGATIVE\n\nRIS CODE: 2NEGATIVE\n
# 98     BI-RADS: 1 - NEGATIVE\n\nRIS CODE: 2NEGATIVE\n
# 99     BI-RADS: 1 - NEGATIVE\n\nRIS CODE: 2NEGATIVE\n
#
#                                         RECOMENDATION  CONCLUSION  CLIP  \
# 0                                                 NaN         NaN     0
# 1                                                 NaN         NaN     0
# 2    \nRoutine screening mammography or combinatio...         NaN     0
# 3    \nRoutine screening mammography or combinatio...         NaN     0
# 4    \nRoutine screening mammography or combinatio...         NaN     0
# ..                                                ...         ...   ...
# 95                                                NaN         NaN     0
# 96                                                NaN         NaN     0
# 97                                                NaN         NaN     0
# 98                                                NaN         NaN     0
# 99   \nRoutine screening mammography or combinatio...         NaN     0
#
#                                              image_id  fold view laterality  \
# 0   1.2.840.113654.2.70.1.250833044448633383274960...     2   CC          R
# 1   1.2.840.113654.2.70.1.218018924783571581641971...     2   CC          R
# 2   1.2.840.113654.2.70.1.159160858633911675764962...     2   CC          R
# 3   1.2.840.113654.2.70.1.104389345981935981355845...     2  MLO          R
# 4   1.2.840.113654.2.70.1.239577423760362698062104...     2   CC          L
# ..                                                ...   ...  ...        ...
# 95  1.2.840.113654.2.70.1.225416017428424459803050...     2   CC          L
# 96  1.2.840.113654.2.70.1.175010212751333265973867...     2   CC          R
# 97  1.2.840.113654.2.70.1.199035556945135657403747...     2  MLO          R
# 98  1.2.840.113654.2.70.1.225334922081844040972632...     2  MLO          L
# 99  1.2.840.113654.2.70.1.657236098764868740735501...     2   CC          L
#
#     img_size_row  img_size_column  BIRADS_numeric
# 0           2456             1995               0
# 1           2456             1995               0
# 2           4096             3328               2
# 3           4096             3328               2
# 4           4096             3328               2
# ..           ...              ...             ...
# 95          2457             1996               1
# 96          2457             1996               1
# 97          2457             1996               1
# 98          2457             1996               1
# 99          4096             3328               1
#
# [100 rows x 19 columns]

# %%
df.to_csv(
    data_dir/csv, 
    index=False
)

# %% [markdown]
# ## Read final data

# %%
new_df = pd.read_csv(data_dir/"upmc_breast_clip_without_period_lower_case.csv")
print(new_df.shape)
new_df["text"][0], new_df["text_augment"][0]
# Out:
# (42, 10)
# ("['the examination shows benign lymph node enlargement further examination may be needed', 'birads : 4 , patient is : 69 years old , and no additional imaging required at this time']",
#  "['the examination shows a benign enlargement of the lymph node may require a further examination', 'birads: 4, patient is: 69 years old, and no further imaging required at this time']")

# %%
new_df.columns
# Out:
# Index(['patient_id', 'laterality', 'image', 'view', 'CC', 'MLO', 'text',
#        'findings', 'impressions', 'text_augment'],
#       dtype='object')

# %%
from sklearn.model_selection import GroupKFold

gkf = GroupKFold(n_splits=4)

new_df['group'] = new_df['patient_id'].astype(str)  + new_df['laterality']

# Apply GroupKFold
new_df['fold'] = -1  # Initialize the fold column
for fold_number, (train_index, test_index) in enumerate(gkf.split(new_df, groups=new_df['group'])):
    new_df.loc[test_index, 'fold'] = fold_number

# Drop the 'group' column if it's no longer needed
new_df.drop(columns=['group'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[280], line 5
#       1 from sklearn.model_selection import GroupKFold
#       3 gkf = GroupKFold(n_splits=4)
# ----> 5 new_df['group'] = new_df['patient_id'] + new_df['laterality']
#       7 # Apply GroupKFold
#       8 new_df['fold'] = -1  # Initialize the fold column
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File /ocean/projects/asc170022p/shg121/anaconda3/envs/breast_clip_rtx_6000/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:116, in _masked_arith_op(x, y, op)
#     114     # See GH#5284, GH#5035, GH#19448 for historical reference
#     115     if mask.any():
# --> 116         result[mask] = op(xrav[mask], yrav[mask])
#     118 else:
#     119     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
type(new_df['patient_id'][0])
# Out:
# numpy.int64
